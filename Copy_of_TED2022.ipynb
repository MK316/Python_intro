# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Python_intro/blob/main/Copy_of_TED2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import modules

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # Upload a file and specify the file name

# %%
# data

file = open("S2022TED.txt")
text = file.read().replace("\n", " ")
file.close()

# %%
# spltxt = text.split()
# len(spltxt)

# %%
# ' '.join(spltxt)

# %% [markdown]
# # Text file = Chapter 1. The Visual Village
# Source: National Geographic Reading series

# %%
# text = """
# The visual village Before the age of the smartphone, \
# aspiring photographers had to learn how to use high-tech cameras and photographic techniques. \
# Not everyone had cameras, and it took skill and a good eye to capture and create a great photograph. Today, with the huge range of camera apps on our smartphones, we are all amateur photographers. And pretty good ones, too: The quality of smartphone images now nearly equals that of digital cameras. The new ease of photography has given us a tremendous appetite for capturing the magical and the ordinary. We are obsessed with documenting everyday moments, whether it’s a shot of our breakfast, our cat – or our cat’s breakfast. And rather than collect pictures in scrapbooks, we share, like, and comment on them with friends and strangers around the globe. Even photojournalists are experimenting with cell phones because their near invisibility makes it easier to capture unguarded media. They can now act as their own publishers – reaching huge audiences via social media sites such as Instagram. A photograph taken in New York can get a response from someone in Lagos within a second of being uploaded. In the past, magazines published unforgettable photos of important people and global events that captured our imaginations. These photos had the power to change public opinion – even the course of history. But if there are fewer memorable images today, it’s not because there are fewer good images: It’s because there are so many. No one image gets to be special for long. Cameras are everywhere – a situation that is transforming the way we experience dramatic events. When there are major political events or natural disasters, it is ordinary citizens with cell phones – not photojournalists – who often provide the first news images. Quality still matters, but it’s less important than what’s instantly shared. As people everywhere embrace photography and the media make use of citizen journalist, professional standards appear to be shifting. In the past, most people trusted photojournalists to accurately represent reality. Today, however, digital images can be altered in ways the naked eye might never notice. Any image can be altered to create an “improved” picture of reality. The average viewer is left with no way to assess the accuracy of an image except through trust in a news organization or photographer. The question of the accuracy of images gets even trickier when photojournalists start experimenting with camera apps – like Flickr or Instagram – which encourage the use of filters. Images can be colored, brightened, faded, and scratched to make photographs more artistic, or to give them an antique look. Photojournalists using camera apps to cover wars and conflicts have created powerful images – but also controversy. Critics worry that antique-looking photographs romanticize war, while distancing us from those who fight in them. Yet, photography has always been more subjective than we assume. Each picture is a result of a series of decisions – where to stand, what lens to use, and what to leave in or out of the frame. Does altering photographs with camera app filters make them less true? There’s something powerful and exciting about the experiment that the digital age has forced upon us. These new tools make it easier to tell our own stories, and they give others the power to do the same. Many members of the media get stuck on the same stories, focusing on elections, governments, wars, and disasters. In the process, they miss out on the less dramatic images of daily life that can be just as revealing and relevant. The increase in the number of photographs and photographers might even be good for democracy itself. Hundreds of millions of potential citizen journalists make the world smaller and help keep leaders honest. People can now show what they are up against, making it increasingly difficult for governments to hide their actions. If everyone has a camera, Big Brother isn’t the only one watching. Who knows? Our obsession with documentation and constantly being connected could lead to a radical change in our way of being. Perhaps we are witnessing the development of a universal visual language. It’s one that could change the way we relate to each other and the world. Of course, as with any language, there will be those who produce poetry and those who make shopping lists. It’s not clear whether this flowering of image-making will lead to a public that better appreciates and understands images. Or will it simply numb us to the profound effects a well-made image can have? Regardless, the change is irreversible. Let’s hope the millions of new photographs made today help us see what we all have in common, rather than what sets us apart.
# """

# %% [markdown]
# # Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# text = nltk.corpus.gutenberg.raw('bible-kjv.txt')

wc = WordCloud().generate(text) 
plt.imshow(wc)

# %% [markdown]
# # Text Preprocessing:

# %%
# word_tokenize: separating punctuation as individual word items
words = word_tokenize(text)
print('Total words including punctuation: ', len(words))
# Out:
# Total words including punctuation:  35140

# %%
# Without punctuation:
wordlist = []

for w in words:
  if len(w) > 1:
    wordlist.append(w)
print('Total words: ', len(wordlist))
print(wordlist)
# Out:
# Total words:  30058
# ['How', 'compassion', 'could', 'save', 'your', 'strained', 'relationships', 'In', 'the', 'last', 'few', 'years', 'cancel', 'culture', 'has', 'of', 'course', 'come', 'into', 'great', 'prominence', 'It', "'s", 'existed', 'throughout', 'time', 'but', 'cancel', 'culture', 'in', 'the', 'bigger', 'society', 'is', 'when', 'person', 'in', 'prominence', 'says', 'or', 'does', 'something', 'that', 'we', 'the', 'people', 'disagree', 'with', 'and', 'the', 'decision', 'is', 'made', 'to', 'make', 'them', 'persona', 'non', 'grata', 'They', 'are', 'done', 'They', 'are', 'not', 'to', 'be', 'revered', 'They', 'are', 'not', 'to', 'be', 'part', 'of', 'our', 'world', 'anymore', 'And', 'that', 'is', 'in', 'the', 'public', 'realm', "'m", 'going', 'to', 'talk', 'to', 'you', 'today', 'about', 'the', 'private', 'realm', 'When', 'we', 'choose', 'to', 'cancel', 'the', 'people', 'in', 'our', 'circle', 'the', 'people', 'in', 'our', 'core', 'the', 'people', 'who', 'love', 'us', 'and', 'who', 'we', 'love', 'and', 'it', 'has', 'been', 'mutually', 'beneficial', 'but', 'due', 'to', 'deep', 'and', 'sincere', 'ideological', 'divide', 'we', 'make', 'the', 'decision', 'to', 'cancel', 'them', 'out', 'of', 'our', 'lives', 'want', 'to', 'suggest', 'that', 'cancel', 'culture', 'needs', 'to', 'change', 'and', 'instead', 'we', 'need', 'to', 'move', 'to', 'compassion', 'culture', 'But', 'before', 'go', 'there', 'let', 'me', 'tell', 'you', 'two', 'of', 'the', 'premises', 'that', 'exist', 'when', 'we', 'indulge', 'in', 'cancel', 'culture', 'One', 'we', 'have', 'to', 'believe', 'that', 'we', "'re", 'right', 'hundred', 'percent', 'no', 'possibility', 'of', 'being', 'wrong', 'And', 'two', 'the', 'other', 'person', 'the', 'person', 'we', "'re", 'going', 'to', 'cancel', 'clearly', 'does', 'not', 'have', 'the', 'ability', 'to', 'change', 'to', 'grow', 'to', 'develop', 'Obviously', 'both', 'of', 'these', 'are', 'problematic', 'because', 'sometimes', 'we', "'re", 'not', 'right', 'do', "n't", 'know', 'about', 'you', 'but', 'there', 'have', 'been', 'times', 'in', 'my', 'life', 'when', 'knew', 'beyond', 'shadow', 'of', 'doubt', 'that', 'was', 'right', 'only', 'to', 'discover', 'that', 'was', 'wrong', 'badly', 'wrong', 'completely', 'missed', 'the', 'mark', 'So', 'if', 'it', 'could', 'happen', 'to', 'me', 'and', 'perhaps', 'it', "'s", 'happened', 'to', 'you', 'perhaps', 'it', 'could', 'happen', 'to', 'others', 'The', 'second', 'is', 'little', 'even', 'more', 'challenging', 'because', 'know', 'that', "'ve", 'changed', 'over', 'the', 'years', "'ve", 'changed', 'And', 'if', "'m", 'able', 'to', 'change', 'should', "n't", 'extend', 'grace', 'to', 'believe', 'that', 'others', 'can', 'change', 'too', 'So', 'what', 'should', 'we', 'do', 'Instead', 'of', 'canceling', 'people', 'we', 'should', 'use', 'the', 'tool', 'called', 'compassion', 'find', 'the', 'definition', 'of', 'compassion', 'is', 'fascinating', 'one', 'And', 'it', "'s", 'not', 'one', 'that', 'hear', 'people', 'talk', 'about', 'Compassion', 'means', 'to', 'suffer', 'with', 'someone', 'To', 'suffer', 'alongside', 'them', 'What', 'if', 'we', "'re", 'the', 'ones', 'to', 'plant', 'seeds', 'of', 'change', 'seeds', 'of', 'influence', 'seeds', 'of', 'difference', 'Now', 'to', 'be', 'fair', 'can', 'not', 'promise', 'you', 'that', 'just', 'because', 'you', 'plant', 'the', 'seed', 'that', 'it', 'will', 'get', 'water', 'that', 'it', "'ll", 'get', 'any', 'sunlight', 'or', 'even', 'little', 'fertilizer', 'But', 'what', 'can', 'tell', 'you', 'is', 'that', 'if', 'you', 'do', "n't", 'plant', 'it', 'who', 'will', 'That', 'if', 'we', 'choose', 'to', 'be', 'curious', 'about', 'that', 'which', 'is', 'different', 'we', 'might', 'discover', 'something', 'along', 'the', 'way', 'After', 'all', 'if', 'we', 'are', 'who', 'we', 'are', 'because', 'of', 'our', 'lived', 'experiences', 'is', "n't", 'that', 'true', 'for', 'someone', 'else', 'And', 'have', 'we', 'ever', 'decided', 'to', 'use', 'that', 'tool', 'of', 'empathy', 'of', 'walking', 'mile', 'or', 'so', 'in' ...

# %%
# Lower case
lowerword = []

for w in wordlist:
  w1 = w.lower()
  lowerword.append(w1)
print(lowerword)
# Out:
# ['how', 'compassion', 'could', 'save', 'your', 'strained', 'relationships', 'in', 'the', 'last', 'few', 'years', 'cancel', 'culture', 'has', 'of', 'course', 'come', 'into', 'great', 'prominence', 'it', "'s", 'existed', 'throughout', 'time', 'but', 'cancel', 'culture', 'in', 'the', 'bigger', 'society', 'is', 'when', 'person', 'in', 'prominence', 'says', 'or', 'does', 'something', 'that', 'we', 'the', 'people', 'disagree', 'with', 'and', 'the', 'decision', 'is', 'made', 'to', 'make', 'them', 'persona', 'non', 'grata', 'they', 'are', 'done', 'they', 'are', 'not', 'to', 'be', 'revered', 'they', 'are', 'not', 'to', 'be', 'part', 'of', 'our', 'world', 'anymore', 'and', 'that', 'is', 'in', 'the', 'public', 'realm', "'m", 'going', 'to', 'talk', 'to', 'you', 'today', 'about', 'the', 'private', 'realm', 'when', 'we', 'choose', 'to', 'cancel', 'the', 'people', 'in', 'our', 'circle', 'the', 'people', 'in', 'our', 'core', 'the', 'people', 'who', 'love', 'us', 'and', 'who', 'we', 'love', 'and', 'it', 'has', 'been', 'mutually', 'beneficial', 'but', 'due', 'to', 'deep', 'and', 'sincere', 'ideological', 'divide', 'we', 'make', 'the', 'decision', 'to', 'cancel', 'them', 'out', 'of', 'our', 'lives', 'want', 'to', 'suggest', 'that', 'cancel', 'culture', 'needs', 'to', 'change', 'and', 'instead', 'we', 'need', 'to', 'move', 'to', 'compassion', 'culture', 'but', 'before', 'go', 'there', 'let', 'me', 'tell', 'you', 'two', 'of', 'the', 'premises', 'that', 'exist', 'when', 'we', 'indulge', 'in', 'cancel', 'culture', 'one', 'we', 'have', 'to', 'believe', 'that', 'we', "'re", 'right', 'hundred', 'percent', 'no', 'possibility', 'of', 'being', 'wrong', 'and', 'two', 'the', 'other', 'person', 'the', 'person', 'we', "'re", 'going', 'to', 'cancel', 'clearly', 'does', 'not', 'have', 'the', 'ability', 'to', 'change', 'to', 'grow', 'to', 'develop', 'obviously', 'both', 'of', 'these', 'are', 'problematic', 'because', 'sometimes', 'we', "'re", 'not', 'right', 'do', "n't", 'know', 'about', 'you', 'but', 'there', 'have', 'been', 'times', 'in', 'my', 'life', 'when', 'knew', 'beyond', 'shadow', 'of', 'doubt', 'that', 'was', 'right', 'only', 'to', 'discover', 'that', 'was', 'wrong', 'badly', 'wrong', 'completely', 'missed', 'the', 'mark', 'so', 'if', 'it', 'could', 'happen', 'to', 'me', 'and', 'perhaps', 'it', "'s", 'happened', 'to', 'you', 'perhaps', 'it', 'could', 'happen', 'to', 'others', 'the', 'second', 'is', 'little', 'even', 'more', 'challenging', 'because', 'know', 'that', "'ve", 'changed', 'over', 'the', 'years', "'ve", 'changed', 'and', 'if', "'m", 'able', 'to', 'change', 'should', "n't", 'extend', 'grace', 'to', 'believe', 'that', 'others', 'can', 'change', 'too', 'so', 'what', 'should', 'we', 'do', 'instead', 'of', 'canceling', 'people', 'we', 'should', 'use', 'the', 'tool', 'called', 'compassion', 'find', 'the', 'definition', 'of', 'compassion', 'is', 'fascinating', 'one', 'and', 'it', "'s", 'not', 'one', 'that', 'hear', 'people', 'talk', 'about', 'compassion', 'means', 'to', 'suffer', 'with', 'someone', 'to', 'suffer', 'alongside', 'them', 'what', 'if', 'we', "'re", 'the', 'ones', 'to', 'plant', 'seeds', 'of', 'change', 'seeds', 'of', 'influence', 'seeds', 'of', 'difference', 'now', 'to', 'be', 'fair', 'can', 'not', 'promise', 'you', 'that', 'just', 'because', 'you', 'plant', 'the', 'seed', 'that', 'it', 'will', 'get', 'water', 'that', 'it', "'ll", 'get', 'any', 'sunlight', 'or', 'even', 'little', 'fertilizer', 'but', 'what', 'can', 'tell', 'you', 'is', 'that', 'if', 'you', 'do', "n't", 'plant', 'it', 'who', 'will', 'that', 'if', 'we', 'choose', 'to', 'be', 'curious', 'about', 'that', 'which', 'is', 'different', 'we', 'might', 'discover', 'something', 'along', 'the', 'way', 'after', 'all', 'if', 'we', 'are', 'who', 'we', 'are', 'because', 'of', 'our', 'lived', 'experiences', 'is', "n't", 'that', 'true', 'for', 'someone', 'else', 'and', 'have', 'we', 'ever', 'decided', 'to', 'use', 'that', 'tool', 'of', 'empathy', 'of', 'walking', 'mile', 'or', 'so', 'in' ...

# %%
# # This separates hyphened words

# from nltk.tokenize import RegexpTokenizer
# retokenize = RegexpTokenizer("[\w]+")
# words = retokenize.tokenize(text)
# len(words)

# %% [markdown]
# # Stopwords

# %%
words = lowerword

# %%
from nltk.corpus import stopwords  
nltk.download('stopwords')
print(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['how', 'compassion', 'could', 'save', 'your', 'strained', 'relationships', 'in', 'the', 'last', 'few', 'years', 'cancel', 'culture', 'has', 'of', 'course', 'come', 'into', 'great', 'prominence', 'it', "'s", 'existed', 'throughout', 'time', 'but', 'cancel', 'culture', 'in', 'the', 'bigger', 'society', 'is', 'when', 'person', 'in', 'prominence', 'says', 'or', 'does', 'something', 'that', 'we', 'the', 'people', 'disagree', 'with', 'and', 'the', 'decision', 'is', 'made', 'to', 'make', 'them', 'persona', 'non', 'grata', 'they', 'are', 'done', 'they', 'are', 'not', 'to', 'be', 'revered', 'they', 'are', 'not', 'to', 'be', 'part', 'of', 'our', 'world', 'anymore', 'and', 'that', 'is', 'in', 'the', 'public', 'realm', "'m", 'going', 'to', 'talk', 'to', 'you', 'today', 'about', 'the', 'private', 'realm', 'when', 'we', 'choose', 'to', 'cancel', 'the', 'people', 'in', 'our', 'circle', 'the', 'people', 'in', 'our', 'core', 'the', 'people', 'who', 'love', 'us', 'and', 'who', 'we', 'love', 'and', 'it', 'has', 'been', 'mutually', 'beneficial', 'but', 'due', 'to', 'deep', 'and', 'sincere', 'ideological', 'divide', 'we', 'make', 'the', 'decision', 'to', 'cancel', 'them', 'out', 'of', 'our', 'lives', 'want', 'to', 'suggest', 'that', 'cancel', 'culture', 'needs', 'to', 'change', 'and', 'instead', 'we', 'need', 'to', 'move', 'to', 'compassion', 'culture', 'but', 'before', 'go', 'there', 'let', 'me', 'tell', 'you', 'two', 'of', 'the', 'premises', 'that', 'exist', 'when', 'we', 'indulge', 'in', 'cancel', 'culture', 'one', 'we', 'have', 'to', 'believe', 'that', 'we', "'re", 'right', 'hundred', 'percent', 'no', 'possibility', 'of', 'being', 'wrong', 'and', 'two', 'the', 'other', 'person', 'the', 'person', 'we', "'re", 'going', 'to', 'cancel', 'clearly', 'does', 'not', 'have', 'the', 'ability', 'to', 'change', 'to', 'grow', 'to', 'develop', 'obviously', 'both', 'of', 'these', 'are', 'problematic', 'because', 'sometimes', 'we', "'re", 'not', 'right', 'do', "n't", 'know', 'about', 'you', 'but', 'there', 'have', 'been', 'times', 'in', 'my', 'life', 'when', 'knew', 'beyond', 'shadow', 'of', 'doubt', 'that', 'was', 'right', 'only', 'to', 'discover', 'that', 'was', 'wrong', 'badly', 'wrong', 'completely', 'missed', 'the', 'mark', 'so', 'if', 'it', 'could', 'happen', 'to', 'me', 'and', 'perhaps', 'it', "'s", 'happened', 'to', 'you', 'perhaps', 'it', 'could', 'happen', 'to', 'others', 'the', 'second', 'is', 'little', 'even', 'more', 'challenging', 'because', 'know', 'that', "'ve", 'changed', 'over', 'the', 'years', "'ve", 'changed', 'and', 'if', "'m", 'able', 'to', 'change', 'should', "n't", 'extend', 'grace', 'to', 'believe', 'that', 'others', 'can', 'change', 'too', 'so', 'what', 'should', 'we', 'do', 'instead', 'of', 'canceling', 'people', 'we', 'should', 'use', 'the', 'tool', 'called', 'compassion', 'find', 'the', 'definition', 'of', 'compassion', 'is', 'fascinating', 'one', 'and', 'it', "'s", 'not', 'one', 'that', 'hear', 'people', 'talk', 'about', 'compassion', 'means', 'to', 'suffer', 'with', 'someone', 'to', 'suffer', 'alongside', 'them', 'what', 'if', 'we', "'re", 'the', 'ones', 'to', 'plant', 'seeds', 'of', 'change', 'seeds', 'of', 'influence', 'seeds', 'of', 'difference', 'now', 'to', 'be', 'fair', 'can', 'not', 'promise', 'you', 'that', 'just', 'because', 'you', 'plant', 'the', 'seed', 'that', 'it', 'will', 'get', 'water', 'that', 'it', "'ll", 'get', 'any', 'sunlight', 'or', 'even', 'little', 'fertilizer', 'but', 'what', 'can', 'tell', 'you', 'is', 'that', 'if', 'you', 'do', "n't", 'plant', 'it', 'who', 'will', 'that', 'if', 'we', 'choose', 'to', 'be', 'curious', 'about', 'that', 'which', 'is', 'different', 'we', 'might', 'discover', 'something', 'along', 'the', 'way', 'after', 'all', 'if', 'we', 'are', 'who', 'we', 'are', 'because', 'of', 'our', 'lived', 'experiences', 'is', "n't", 'that', 'true', 'for', 'someone', 'else', 'and', 'have', 'we', 'ever', 'decided', 'to', 'use', 'that', 'tool', 'of', 'empathy', 'of', 'walking', 'mile', 'or', 'so', 'in' ...

# %%
# Removing stopwords: 'the' 'a' 'to' 'from' etc.

words = [w for w in words if not w in stopwords.words('english')]
print(words)
print(len(words))
# Out:
# ['compassion', 'could', 'save', 'strained', 'relationships', 'last', 'years', 'cancel', 'culture', 'course', 'come', 'great', 'prominence', "'s", 'existed', 'throughout', 'time', 'cancel', 'culture', 'bigger', 'society', 'person', 'prominence', 'says', 'something', 'people', 'disagree', 'decision', 'made', 'make', 'persona', 'non', 'grata', 'done', 'revered', 'part', 'world', 'anymore', 'public', 'realm', "'m", 'going', 'talk', 'today', 'private', 'realm', 'choose', 'cancel', 'people', 'circle', 'people', 'core', 'people', 'love', 'us', 'love', 'mutually', 'beneficial', 'due', 'deep', 'sincere', 'ideological', 'divide', 'make', 'decision', 'cancel', 'lives', 'want', 'suggest', 'cancel', 'culture', 'needs', 'change', 'instead', 'need', 'move', 'compassion', 'culture', 'go', 'let', 'tell', 'two', 'premises', 'exist', 'indulge', 'cancel', 'culture', 'one', 'believe', "'re", 'right', 'hundred', 'percent', 'possibility', 'wrong', 'two', 'person', 'person', "'re", 'going', 'cancel', 'clearly', 'ability', 'change', 'grow', 'develop', 'obviously', 'problematic', 'sometimes', "'re", 'right', "n't", 'know', 'times', 'life', 'knew', 'beyond', 'shadow', 'doubt', 'right', 'discover', 'wrong', 'badly', 'wrong', 'completely', 'missed', 'mark', 'could', 'happen', 'perhaps', "'s", 'happened', 'perhaps', 'could', 'happen', 'others', 'second', 'little', 'even', 'challenging', 'know', "'ve", 'changed', 'years', "'ve", 'changed', "'m", 'able', 'change', "n't", 'extend', 'grace', 'believe', 'others', 'change', 'instead', 'canceling', 'people', 'use', 'tool', 'called', 'compassion', 'find', 'definition', 'compassion', 'fascinating', 'one', "'s", 'one', 'hear', 'people', 'talk', 'compassion', 'means', 'suffer', 'someone', 'suffer', 'alongside', "'re", 'ones', 'plant', 'seeds', 'change', 'seeds', 'influence', 'seeds', 'difference', 'fair', 'promise', 'plant', 'seed', 'get', 'water', "'ll", 'get', 'sunlight', 'even', 'little', 'fertilizer', 'tell', "n't", 'plant', 'choose', 'curious', 'different', 'might', 'discover', 'something', 'along', 'way', 'lived', 'experiences', "n't", 'true', 'someone', 'else', 'ever', 'decided', 'use', 'tool', 'empathy', 'walking', 'mile', 'someone', 'else', "'s", 'shoes', 'really', 'discover', 'context', 'believe', 'believe', 'encouraging', 'us', 'become', 'society', 'people', 'choose', 'compassion', 'canceling', "'m", 'asking', 'us', 'consider', 'curiosity', 'might', 'better', 'practice', 'might', 'choose', 'empathy', 'might', 'choose', 'love', 'deep', 'wide', 'strong', 'surpass', 'differences', 'scared', 'differences', 'anyway', 'also', 'want', 'us', 'people', 'plant', 'seeds', 'seeds', 'change', 'seeds', 'influence', 'seeds', 'diversity', 'promise', 'anyone', 'else', 'planting', 'seed', 'going', 'make', 'difference', 'mind', 'changed', 'years', 'grown', 'people', 'life', 'planted', 'seeds', 'saw', "n't", 'would', "n't", 'great', 'instead', 'cancel', 'culture', 'create', 'compassion', 'culture', 'willing', 'suffer', 'alongside', 'ones', 'love', 'love', 'ca', "n't", 'become', 'community', 'plants', 'seeds', "n't", 'thank', 'create', 'perfect', 'farm', '10,000', 'years', 'ago', 'humans', 'began', 'farm', 'agricultural', 'revolution', 'turning', 'point', 'history', 'enabled', 'people', 'settle', 'build', 'create', 'short', 'agriculture', 'enabled', 'existence', 'civilization', 'today', 'approximately', '40', 'percent', 'planet', 'farmland', 'spread', 'world', 'agricultural', 'lands', 'pieces', 'global', 'puzzle', 'facing', 'future', 'feed', 'every', 'member', 'growing', 'population', 'healthy', 'diet', 'meeting', 'goal', 'require', 'nothing', 'short', 'second', 'agricultural', 'revolution', 'first', 'agricultural', 'revolution', 'characterized', 'expansion', 'exploitation', 'agriculture', 'depends', 'stable', 'climate', 'predictable', 'seasons', 'weather', 'patterns', 'means', 'ca', "n't", 'keep', 'expanding', 'agricultural', 'lands', 'undermine', 'environmental', 'conditions', 'make', 'agriculture', 'possible', 'first', 'pla ...
# 15380

# %% [markdown]
# # Word frequency

# %%
# Frequency distribution:

fd = nltk.FreqDist(words).most_common(20)
fd
# Out:
# [("'s", 349),
#  ('people', 182),
#  ("n't", 182),
#  ("'re", 141),
#  ('one', 115),
#  ('``', 115),
#  ("''", 110),
#  ('us', 105),
#  ('like', 95),
#  ('would', 76),
#  ('time', 73),
#  ('really', 72),
#  ('think', 72),
#  ('see', 65),
#  ('get', 63),
#  ('much', 61),
#  ('things', 61),
#  ('world', 58),
#  ('know', 56),
#  ('life', 54)]

# %%
# Low frequency words

fd2 = nltk.FreqDist(words).most_common()[-20:]
fd2
# Out:
# [('stripped', 1),
#  ('weaving', 1),
#  ('daily', 1),
#  ('weave', 1),
#  ('baskets', 1),
#  ('construction', 1),
#  ('enterprise', 1),
#  ('expert', 1),
#  ('beekeepers', 1),
#  ('basket', 1),
#  ('weavers', 1),
#  ('chili', 1),
#  ('sunflower', 1),
#  ('lip', 1),
#  ('balms', 1),
#  ('participating', 1),
#  ('eco-generating', 1),
#  ('projects', 1),
#  ('forefront', 1),
#  ('boldly', 1)]

# %% [markdown]
# # Word collocation & concordance

# %%
import re
result = [w for w in words if re.search('^really', w)]
fd3 = nltk.FreqDist(result); print('#really가 들어가는 단어수: %d'%len(fd3), 'types')
# Out:
# #really가 들어가는 단어수: 1 types

# %%
# Photo가 들어가는 단어 목록과 빈도:
fd3
# Out:
# FreqDist({'really': 72})

# %%
# Concordance:
words1 = text.split()
nltk.Text(words1).concordance('really', 89, 10)
# Out:
# Displaying 10 of 68 matches:
#  a mile or so in someone else's shoes to really discover the context for why they believ
# biggest reason why start-ups succeed I'm really excited to share with you some findings
# ted to share with you some findings that really surprise me about what makes companies s
#  all of these companies, and the results really surprised me. The number one thing was t
#  the height of the recession when people really needed extra money, and that maybe helpe
# ht matter even more. And the best way to really assess timing is to really look at wheth
# e best way to really assess timing is to really look at whether consumers are really rea
#  to really look at whether consumers are really ready for what you have to offer them. A
# ou have to offer them. And to be really, really honest about it, not be in denial about
#  out of my mind. I kept thinking, can it really have taken us over 2,000 years to come t

# %%
words1 = text.split()
nltk.Text(words1).concordance('really', 89, 72)
# Out:
# Displaying 68 of 68 matches:
#  a mile or so in someone else's shoes to really discover the context for why they believ
# biggest reason why start-ups succeed I'm really excited to share with you some findings
# ted to share with you some findings that really surprise me about what makes companies s
#  all of these companies, and the results really surprised me. The number one thing was t
#  the height of the recession when people really needed extra money, and that maybe helpe
# ht matter even more. And the best way to really assess timing is to really look at wheth
# e best way to really assess timing is to really look at whether consumers are really rea
#  to really look at whether consumers are really ready for what you have to offer them. A
# ou have to offer them. And to be really, really honest about it, not be in denial about
#  out of my mind. I kept thinking, can it really have taken us over 2,000 years to come t
# gence, and if that’s the case, can we be really comfortable with the thought that we're
#  journalist to deal with the world as it really is, and this must go hand in hand with t
# for size. Wow! So, mundane sounds can be really interesting -- if you pay attention. I c
# ake a positive change?] You know, if you really have been responsible, responsibly hurt
# e it's hard to fix something that you're really not responsible for. It leaves you in a
# and not to feel guilt about that, and to really check, "Is this my responsibility?" Then
# ed of, which is who we are. So there's a really unfair shame, shame over having a stigma
#  you buy into that, and I think that's a really big question to work with. [What strateg
# o some double-checking, you know, "Is it really fair for me to feel like a bad person be
# buying into internalized shame, that's a really good question. I think, first of all, fi
# r people's expectation, that's a really, really important one, and I think it's critical
# , but I'm doing Y, and this is why. It's really important to me.“ How to buy happiness S
# 't matter how much money you spent. What really matters is that you spent it on somebody
# like somersaulting and silly walks. It's really common. So is twitching along the floor
#  kind of weird force of nature. And it's really easy to accidentally give AI the wrong p
#  happens all the time with AI. AI can be really destructive and not know it. So the AIs
# h its tiny little worm brain, AI doesn't really understand what we're trying to ask it t
# e zone, a less pleasant place, but where really important things happen? Well, turns out
# hing - we need to think about what we're really procrastinating on, because everyone is
# st 10 years. And this enabled us to do a really interesting kind of analysis, because it
# ars older all say, "Eh, you know, that's really changed." Does any of this matter? Is th
# mingly impossible keeps becoming reality really fast lately. So teachers jumped and adap
# nce always to make what seems impossible really happen. And when the stakes are this hig
# vels we see in early adulthood. Now it's really too simplistic to say that older people
#  the most. And under conditions where it really matters, older people do process the neg
#  today's world, their situation would be really dire, but think about how much worse it
# , we called them stories? Because that's really what fear is, if you think about it. It'
# n. We studied rookie teachers working in really tough neighborhoods, asking which teache
# or the month, but for years, and working really hard to make that future a reality. Grit
#  years old. And the truth is that no one really cares what you say when you're that age.
# everyone else do? How do they operate? I really think that this is all based on the idea
# , how often do you laugh at work? I mean really laugh. We asked some of you this questio
# e willing to pay nearly 20 percent more. Really let it sink in, just how bad that joke i
# al information, so they feel closer. You really laughed hard at that "pet frog" line. I
#  to it. Alright, so humor works. And the really good news that we want to talk about tod
# quire a lot of effort, because change is really hard. To establish an exercise routine,
#  too distracted to do the things that we really do intend to do and to be the people tha
# t that was missing. And these things are really a global failure. The WHO is funded to m
# e concerned. But in fact, we can build a really good response system. We have the benefi
# imple enough but I was missing something really important. So why is it so hard to pay a
#  Well, studies show that even when we're really trying to pay attention to something - l
# s what mindfulness is all about : Seeing really clearly what we get when we get caught u
#  is that mindfulness is just about being really interested in getting close and personal
# r, how their dialects work. And we don't really understand yet how they navigate the lan
# se most magnificent of all animals. It's really hard not to have watched a documentary,
# ent game reserves in Southern Africa. It really was heaven for a young, budding zoologis
# communities out of their wild spaces. It really was quite a challenge to me at that youn
# re now that I feel truly, instinctively, really at home. I spent many, many happy years
# eing fragmented at such a pace that it's really hard to keep up with. Too often, these m
# breaking into food stores for food. It's really a huge challenge. Can you imagine the te
# ther, particularly if they're blocking a really special water hole where they need water
# munity side of the fence. And now you're really in trouble. People keep trying to come u
# ing these hard-line, straight, electric, really divisive migratory-blocking fences, ther
# remember that very quickly. And it's not really one sting that they're scared of. Africa
# he area. So these behavioral discoveries really helped us understand how elephants would
# nking there are more beehives than there really are. And of course, it literally halves
# The bees swarm out of the hive, and they really scare the elephants away. These beehive
# s. The strength of the beehive fences is really important -- the colonies have to be ver

# %%
nltk.Text(words1).collocations()
# Out:
# Thank you.; older people; beehive fences; years ago,; ice cream; Panic
# Monster; air pollution; younger people; cancel culture; like this.;
# ginger beer; life expectancy; business model; United States; things
# like; years old,; looks like; agricultural revolution; favorite
# musician; grow up?"

# %%
# text2 = text.replace("cameras","camera")
# text3 = text2.replace("photographs","photograph")
# words3 = text3.split()
# print(words3)
# Out:
# ['The', 'visual', 'village', 'Before', 'the', 'age', 'of', 'the', 'smartphone,', 'aspiring', 'photographers', 'had', 'to', 'learn', 'how', 'to', 'use', 'high-tech', 'camera', 'and', 'photographic', 'techniques.', 'Not', 'everyone', 'had', 'camera,', 'and', 'it', 'took', 'skill', 'and', 'a', 'good', 'eye', 'to', 'capture', 'and', 'create', 'a', 'great', 'photograph.', 'Today,', 'with', 'the', 'huge', 'range', 'of', 'camera', 'apps', 'on', 'our', 'smartphones,', 'we', 'are', 'all', 'amateur', 'photographers.', 'And', 'pretty', 'good', 'ones,', 'too:', 'The', 'quality', 'of', 'smartphone', 'images', 'now', 'nearly', 'equals', 'that', 'of', 'digital', 'camera.', 'The', 'new', 'ease', 'of', 'photography', 'has', 'given', 'us', 'a', 'tremendous', 'appetite', 'for', 'capturing', 'the', 'magical', 'and', 'the', 'ordinary.', 'We', 'are', 'obsessed', 'with', 'documenting', 'everyday', 'moments,', 'whether', 'it’s', 'a', 'shot', 'of', 'our', 'breakfast,', 'our', 'cat', '–', 'or', 'our', 'cat’s', 'breakfast.', 'And', 'rather', 'than', 'collect', 'pictures', 'in', 'scrapbooks,', 'we', 'share,', 'like,', 'and', 'comment', 'on', 'them', 'with', 'friends', 'and', 'strangers', 'around', 'the', 'globe.', 'Even', 'photojournalists', 'are', 'experimenting', 'with', 'cell', 'phones', 'because', 'their', 'near', 'invisibility', 'makes', 'it', 'easier', 'to', 'capture', 'unguarded', 'media.', 'They', 'can', 'now', 'act', 'as', 'their', 'own', 'publishers', '–', 'reaching', 'huge', 'audiences', 'via', 'social', 'media', 'sites', 'such', 'as', 'Instagram.', 'A', 'photograph', 'taken', 'in', 'New', 'York', 'can', 'get', 'a', 'response', 'from', 'someone', 'in', 'Lagos', 'within', 'a', 'second', 'of', 'being', 'uploaded.', 'In', 'the', 'past,', 'magazines', 'published', 'unforgettable', 'photos', 'of', 'important', 'people', 'and', 'global', 'events', 'that', 'captured', 'our', 'imaginations.', 'These', 'photos', 'had', 'the', 'power', 'to', 'change', 'public', 'opinion', '–', 'even', 'the', 'course', 'of', 'history.', 'But', 'if', 'there', 'are', 'fewer', 'memorable', 'images', 'today,', 'it’s', 'not', 'because', 'there', 'are', 'fewer', 'good', 'images:', 'It’s', 'because', 'there', 'are', 'so', 'many.', 'No', 'one', 'image', 'gets', 'to', 'be', 'special', 'for', 'long.', 'Cameras', 'are', 'everywhere', '–', 'a', 'situation', 'that', 'is', 'transforming', 'the', 'way', 'we', 'experience', 'dramatic', 'events.', 'When', 'there', 'are', 'major', 'political', 'events', 'or', 'natural', 'disasters,', 'it', 'is', 'ordinary', 'citizens', 'with', 'cell', 'phones', '–', 'not', 'photojournalists', '–', 'who', 'often', 'provide', 'the', 'first', 'news', 'images.', 'Quality', 'still', 'matters,', 'but', 'it’s', 'less', 'important', 'than', 'what’s', 'instantly', 'shared.', 'As', 'people', 'everywhere', 'embrace', 'photography', 'and', 'the', 'media', 'make', 'use', 'of', 'citizen', 'journalist,', 'professional', 'standards', 'appear', 'to', 'be', 'shifting.', 'In', 'the', 'past,', 'most', 'people', 'trusted', 'photojournalists', 'to', 'accurately', 'represent', 'reality.', 'Today,', 'however,', 'digital', 'images', 'can', 'be', 'altered', 'in', 'ways', 'the', 'naked', 'eye', 'might', 'never', 'notice.', 'Any', 'image', 'can', 'be', 'altered', 'to', 'create', 'an', '“improved”', 'picture', 'of', 'reality.', 'The', 'average', 'viewer', 'is', 'left', 'with', 'no', 'way', 'to', 'assess', 'the', 'accuracy', 'of', 'an', 'image', 'except', 'through', 'trust', 'in', 'a', 'news', 'organization', 'or', 'photographer.', 'The', 'question', 'of', 'the', 'accuracy', 'of', 'images', 'gets', 'even', 'trickier', 'when', 'photojournalists', 'start', 'experimenting', 'with', 'camera', 'apps', '–', 'like', 'Flickr', 'or', 'Instagram', '–', 'which', 'encourage', 'the', 'use', 'of', 'filters.', 'Images', 'can', 'be', 'colored,', 'brightened,', 'faded,', 'and', 'scratched', 'to', 'make', 'photograph', 'more', 'artistic,', 'or', 'to', 'give', 'them', 'an', 'antique', 'look.', 'Photojou ...

# %%
nltk.Text(words1).dispersion_plot(["people","one","us","really"])

# %% [markdown]
# # Additional

# %%
# longest words

print(len(words))

print('Longest word: ', max(len(w) for w in words), 'letters')
# Out:
# 15380
# Longest word:  24 letters

# %%
fd = nltk.FreqDist(words)
fd

wlist = []

for w in fd:
  if len(w) > 15:
    wlist.append(w)
    print(w)

print('총: ',len(wlist), '개 단어')
# Out:
# conservation-oriented
# differentiability
# neurotransmitters
# responsibilities
# self-compassionate
# traditional-style
# non-procrastinator
# non-procrastinators
# conscientiousness
# life-threatening
# multipotentialite
# multipotentialites
# multidimensional
# underappreciated
# better-than-nothing
# adeno-associated
# evolutionarily-conserved
# context-dependent
# douglas-hamilton
# migratory-blocking
# pollinator-friendly
# elephant-friendly
# 총:  22 개 단어

# %%
fd = nltk.FreqDist(words)
fd
len(fd)


# for i in len(fd):
#   if fd[i] > 10:
#     print(fd[i])
# Out:
# 4204

# %%
import pandas

# %%
flist = pd.DataFrame.from_dict(fd, orient='index').T
print(flist)
# Out:
#    compassion  could  save  strained  relationships  last  years  cancel  \
# 0           8     47     7         1              3    17     47       8
#
#    culture  course  ...  chili  oils  sunflower  lip  balms  participating  \
# 0       11      13  ...      1     2          1    1      1              1
#
#    eco-generating  projects  forefront  boldly
# 0               1         1          1       1
#
# [1 rows x 4204 columns]

# %%
flist.to_csv('filename.csv', index=False)

#index =false removes unnecessary indexing/numbering in the csv
